# %% [markdown]
# Попытка создания классификатора базирующегося на результатах фитинга полиномом

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from scipy import signal
from sklearn import tree
from sklearn import neighbors
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
def polyfit(data, polynomialOrder=15):
    res_filter = data
    # Фитируем получившийся массив:
    xData = range(len(res_filter))
    yData = res_filter
    # curve fit the data
    fittedParameters = np.polyfit(xData, yData, polynomialOrder)
    xModel = np.linspace(min(xData), max(xData), len(xData))
    yModel = np.polyval(fittedParameters, xModel)

    return yModel, fittedParameters

# %%
gp_table = pd.read_table('./crab_gp_kaz_10_2016-2018_calib_7types.csv', sep='\t')

# %%
param_set = pd.DataFrame(columns=[f'param_{i}'  for i in range(10)])
param_set['type'] = None

# %%
for idx, _ in enumerate(gp_table['Date']):
    file = './results_by_08.05.2019/' + gp_table['fName'][idx][2:]
    profile = np.genfromtxt(file, skip_header=6)
    
    if len(profile) == 100:
        pass
    else:
        profile = np.append(profile, np.zeros(100 - len(profile)))
            
    profile = profile/np.max(profile)
    pol, param = polyfit(profile, 9)
    param_set.loc[idx] = [
        *param,
        int(gp_table['Type'][idx])
        ]

# %%
param_set
# Out:
#            param_0       param_1       param_2       param_3   param_4  \
# 0    -1.035116e-14  4.853296e-12 -9.548188e-10  1.020874e-07 -0.000006
# 1    -6.182543e-15  2.886756e-12 -5.639929e-10  5.961020e-08 -0.000004
# 2    -8.700538e-15  4.047552e-12 -7.896243e-10  8.364674e-08 -0.000005
# 3    -9.053634e-15  4.179394e-12 -8.111771e-10  8.581421e-08 -0.000005
# 4    -6.737777e-15  3.151538e-12 -6.188132e-10  6.605758e-08 -0.000004
# ...            ...           ...           ...           ...       ...
# 2618 -6.727212e-15  3.223511e-12 -6.500793e-10  7.149765e-08 -0.000005
# 2619 -1.149315e-14  5.239371e-12 -9.989360e-10  1.031459e-07 -0.000006
# 2620 -3.425009e-15  1.569219e-12 -2.994505e-10  3.055303e-08 -0.000002
# 2621 -9.345274e-15  4.316345e-12 -8.374315e-10  8.836229e-08 -0.000005
# 2622 -5.936080e-15  2.667812e-12 -4.985640e-10  4.992542e-08 -0.000003
#
#        param_5   param_6   param_7   param_8   param_9  type
# 0     0.000237 -0.004839  0.044238 -0.047353 -0.104427   6.0
# 1     0.000131 -0.002475  0.017374  0.064648 -0.119527   6.0
# 2     0.000190 -0.003793  0.032778 -0.004696 -0.137460   6.0
# 3     0.000198 -0.004055  0.037186 -0.030673 -0.124598   6.0
# 4     0.000152 -0.003071  0.026299  0.006358 -0.075897   6.0
# ...        ...       ...       ...       ...       ...   ...
# 2618  0.000179 -0.003864  0.040380 -0.130134  0.159197   4.0
# 2619  0.000222 -0.004456  0.043826 -0.148196  0.208608   4.0
# 2620  0.000055 -0.000685 -0.005169  0.172138 -0.321642   4.0
# 2621  0.000200 -0.004017  0.036393 -0.050527 -0.149748   4.0
# 2622  0.000092 -0.001362  0.000233  0.182941 -0.282255   6.0
#
# [2623 rows x 11 columns]

# %%
corr = param_set.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col3 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col4 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col5 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col6 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col7 {
#             background-color:  #4e68d8;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col8 {
#             background-color:  #e46e56;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col9 {
#             background-color:  #f7b99e;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow0_col10 {
#             background-color:  #5875e1;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col0 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col4 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col5 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col6 {
#             background-color:  #4358cb;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col7 {
#             background-color:  #ca3b37;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col8 {
#             background-color:  #5d7ce6;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col9 {
#             background-color:  #6f92f3;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow1_col10 {
#             background-color:  #f59f80;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col1 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col4 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col5 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col6 {
#             background-color:  #bd1f2d;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col7 {
#             background-color:  #485fd1;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col8 {
#             background-color:  #df634e;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col9 {
#             background-color:  #f7ba9f;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow2_col10 {
#             background-color:  #5572df;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col0 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col5 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col6 {
#             background-color:  #3e51c5;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col7 {
#             background-color:  #c32e31;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col8 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col9 {
#             background-color:  #7093f3;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow3_col10 {
#             background-color:  #f59c7d;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col0 {
#             background-color:  #b8122a;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col1 {
#             background-color:  #3c4ec2;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col2 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col3 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col5 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col6 {
#             background-color:  #b70d28;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col7 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col8 {
#             background-color:  #d65244;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col9 {
#             background-color:  #f7bca1;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow4_col10 {
#             background-color:  #536edd;
#             color:  #000000;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow5_col0 {
#             background-color:  #4055c8;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow5_col1 {
#             background-color:  #ba162b;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow5_col2 {
#             background-color:  #3d50c3;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow5_col3 {
#             background-color:  #b50927;
#             color:  #f1f1f1;
#         }    #T_113e3712_e5be_11e9_af76_001b11c4043crow5_col4 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1

# %%
X = param_set.drop(['type'], axis=1)
y = param_set['type']

# %%
grr = pd.plotting.scatter_matrix(X, c=y, figsize=(15, 15), marker='o',
                                 hist_kwds={'bins': 20}, s=60, alpha=.8)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
predictions = clf.predict(X_test)
print(accuracy_score(predictions, y_test))
# Out:
# 0.5895806861499364

# %%
clf = neighbors.KNeighborsClassifier()
clf = clf.fit(X_train, y_train)
predictions = clf.predict(X_test)
print(accuracy_score(predictions, y_test))
# Out:
# 0.6048284625158831

# %%
data_pulse = param_set.where(param_set.type==1, axis=1).dropna()
data_noise = param_set.where(param_set.type==0, axis=1).dropna()

# %%
for lbl in data_pulse.columns:
    bins = np.linspace(min(param_set[lbl]), max(param_set[lbl]), 100)
    plt.close()
    plt.title(lbl)
    plt.hist([data_pulse[lbl ], data_noise[lbl]],
             bins=bins, stacked=True, color=['b', 'r'])
    plt.show()

# %%
# Out:
# 3
