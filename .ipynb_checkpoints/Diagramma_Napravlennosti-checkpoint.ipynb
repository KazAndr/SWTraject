# %%
import matplotlib.pyplot as plt
import numpy as np
from tqdm import tqdm_notebook

# %% [markdown]
# Реализовать отрисовку графика в особой точке x = 0
# Данные по оси ОX должны задаваться подмодулем numpy.linspace

# %%
diag = []
for x in tqdm_notebook(np.linspace(-1.2, 1.2, 83028)):
    if x == 0:
        diag.append(1)
    else:
        diag.append((np.sin(x)/x)**2)
# Out:
# HBox(children=(IntProgress(value=0, max=83028), HTML(value='')))

# %%
#diag = [i for i in diag if i > 0.5]

# %%
plt.close()
plt.plot(diag, 'bo')
plt.show()

# %%
data = [i + 100 for i in diag]

# %%
plt.close()
plt.plot(data, 'bo')
plt.show()

# %%
cor_d = []
for data_point, coeff in zip(data, diag):
    cor_d.append(data_point/coeff)

# %%
plt.close()
plt.plot(cor_d, 'bo')
plt.show()

# %%
cor_d_test = [i + (1 - i) for i in diag]

# %%
plt.close()
plt.plot(cor_d_test, 'bo')
plt.show()

# %%
diag[0]
# Out:
# 0.6032617067851547

# %%
import os
import sys
import glob
import datetime

# %%
_ = "F:\\YandexDisk\\3.Programing\\"
PACK_DIR = _ + "myPacks\\"
PATTERN_DIR = _ + "work\\PulseViewer\\frame_of_AP\\patterns\\"
sys.path.append(PACK_DIR)
from PRAO import *

# %%
head, main_pulse, data_pulses, back = read_profiles_MD('new_data/311017_0531+21_00_profiles.txt')

# %%
non_cor_data = []
for pulse, backg in zip(data_pulses, back):
    non_cor_data.append(pulse + backg)

# %%
obser = np.hstack(non_cor_data)

# %%
plt.close()
plt.plot(obser)
plt.show()

# %%
len(obser)
# Out:
# 80586

# %%
cor_d = []
for data_point, coeff in zip(obser, diag):
    cor_d.append(data_point/coeff)
cor_d = np.asarray(cor_d)

# %%
cor_d = cor_d.reshape(int(head['numpuls'])-1, int(head['numpointwin']))

# %%
plt.close()
plt.plot(cor_d)
#plt.savefig('crab_observ_' + head['date'] + '.png', format='png', dpi=100)
plt.show()

# %%
plt.close()
plt.plot(cor_d_2[-1*2442:])
#plt.savefig('anomaly_end_' + head['date'] + '.png', format='png', dpi=100)
plt.show()

# %%
test = cor_d_2[-1*2442:]

# %%
np.median(test[:6])
# Out:
# 371.18219626271247

# %%
np.median(test[-5:])
# Out:
# 354.1759794125142

# %%
coef = np.linspace(np.median(test[:11]), np.median(test[-10:]), len(test))

# %%
coef_test = []
for point, cf in zip(test, coef):
    coef_test.append(point-cf)

# %%
plt.close()
plt.plot(coef_test)
#plt.savefig('anomaly_start_' + head['date'] + '.png', format='png', dpi=100)
plt.show()

# %%
plt.close()
plt.plot(cor_d_2[:5*2442])
#plt.savefig('anomaly_start_' + head['date'] + '.png', format='png', dpi=100)
plt.show()

# %%
plt.close()
plt.plot(cor_d_2[13*2442:-13*2442])
#plt.savefig('anomaly_mid_' + head['date'] + '.png', format='png', dpi=100)
plt.show()

# %%
plt.close()
plt.plot(cor_d_2)
#plt.savefig('crab_observ_' + head['date'] + '.png', format='png', dpi=100)
plt.show()

# %%
from scipy.interpolate import InterpolatedUnivariateSpline

# %%
inter_point = len(cor_d_2)/10000
    
point_for_pulse = range(len(cor_d_2))
    
spl = InterpolatedUnivariateSpline(point_for_pulse, cor_d_2)
xs = np.linspace(0, len(point_for_pulse)-1, inter_point) # подумать об увеличении количества точек для интерполяции
    
spline = spl(xs)
# Out:
# c:\users\professional\appdata\local\programs\python\python35\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: object of type <class 'float'> cannot be safely interpreted as an integer.

# %%
plt.close()
plt.plot(cor_d_2)
plt.plot(xs, spline, color='r')
#plt.savefig('crab_observ_' + head['date'] + '.png', format='png', dpi=100)
plt.show()

# %% [markdown]
# ### Вычет излучения туманности из данных

# %%
final_array = []
for pulse in cor_d:
    l_edge = np.median(pulse[:6])
    r_edge = np.median(pulse[-5:])
    array_coef = np.linspace(l_edge, r_edge, len(pulse))
    coef_pulse = []
    for point, cf in zip(pulse, array_coef):
        coef_pulse.append(point-cf)
    final_array.append(coef_pulse)
final_array = np.asarray(final_array)
flat_obser = np.hstack(final_array)

# %%
flat_obser_calib = flat_obser + 1400

# %%
plt.close()
plt.plot(flat_obser_calib)
#plt.axhline(np.median(flat_obser_calib), color='r')
#plt.axhline(np.median(flat_obser_calib)*3, color='pink')
#plt.savefig('crab_observ_' + head['date'] + '.png', format='png', dpi=100)
plt.show()

# %%
plt.close()
plt.plot(final_array[13][1800:2000])
#plt.savefig('crab_observ_' + head['date'] + '.png', format='png', dpi=100)
plt.show()

# %%
head
# Out:
# {'F0': '109584',
#  'F511': '112079.1171875',
#  'Fcomp': '111878.921875',
#  'date': '31.10.2017',
#  'dm': '56.77',
#  'f_point_win': '0',
#  'l_point_win': '2441',
#  'name': '0531+21',
#  'numpar': '15',
#  'numpointwin': '2442',
#  'numpuls': '34',
#  'period': '6.00558571814',
#  'sumchan': 'no',
#  'tay': '2.4576',
#  'time': '03:23:28.5208892'}
