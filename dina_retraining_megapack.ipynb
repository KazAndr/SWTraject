# %%
import os 
import glob
import datetime

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.externals import joblib
# Out:
# /home/andr/.pyenv/versions/3.7.4/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: FutureWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=FutureWarning)

# %%
gp_table = pd.read_table('typized_dataset_for_dina_megaset.csv', sep='\t')

# %%
gp_table
# Out:
#         point_0   point_1   point_2   point_3   point_4   point_5   point_6  \
# 0      0.978982  0.600792  0.576295  0.879071  0.748419  0.700882  0.808217
# 1     -0.046221 -0.016026 -0.069947 -0.017973 -0.028160 -0.005879 -0.122640
# 2      0.027795  0.037606  0.040863  0.135837  0.024407  0.015284  0.004629
# 3     -0.092483  0.024088  0.145415  0.193473  0.088773  0.035256 -0.001771
# 4     -0.245618 -0.215813 -0.155470  0.132695  0.247526  0.153856 -0.098590
# ...         ...       ...       ...       ...       ...       ...       ...
# 30095 -0.045956 -0.024024 -0.002831  0.030766  0.016950  0.010178  0.002656
# 30096 -0.046713 -0.079228 -0.011660  0.122095  0.044002 -0.057404 -0.112664
# 30097  0.011909  0.028410 -0.027651  0.016606 -0.013588  0.021380 -0.055476
# 30098  0.449334  0.494104  0.414751  0.301929  0.474813  0.378049  0.496939
# 30099 -0.028517 -0.068501  0.020424 -0.012058  0.009310 -0.071810 -0.093021
#
#         point_7   point_8   point_9  ...  point_141  point_142  point_143  \
# 0      0.756189  0.937267  0.656817  ...  -0.170598  -0.040731   0.055434
# 1     -0.022876 -0.030940  0.005005  ...   0.061523   0.025700   0.118280
# 2     -0.028649 -0.050140  0.122780  ...   0.024338  -0.025538   0.049220
# 3     -0.055982  0.000804  0.064992  ...  -0.027176   0.022993   0.010239
# 4      0.013599  0.015258  0.103669  ...   0.184631  -0.052737  -0.169983
# ...         ...       ...       ...  ...        ...        ...        ...
# 30095  0.021405 -0.026715 -0.003883  ...   0.030998   0.107310   0.069951
# 30096 -0.110412 -0.007963 -0.023589  ...   0.042004  -0.025379  -0.031888
# 30097 -0.044285 -0.003765  0.012023  ...   0.043173   0.038468   0.035248
# 30098  0.623295  0.415871  0.418447  ...   0.000000   0.000000   0.000000
# 30099 -0.015372 -0.046522  0.007986  ...  -0.004039   0.045943   0.017681
#
#        point_144  point_145  point_146  point_147  point_148  point_149  type
# 0      -0.030381  -0.060119   0.038711  -0.207188  -0.327987  -0.026227   0.0
# 1       0.067003   0.090839  -0.069283  -0.008646   0.067241   0.045706   1.0
# 2      -0.024554   0.048421  -0.001028   0.128556   0.105247   0.081709   1.0
# 3      -0.031870   0.022775   0.082362   0.054780   0.058370   0.025668   1.0
# 4      -0.157704   0.415985   0.178661   0.228058   0.099832  -0.275830   0.0
# ...          ...        ...        ...        ...        ...        ...   ...
# 30095   0.133985   0.092593   0.069622   0.071456   0.031802   0.019237   1.0
# 30096  -0.051869  -0.023643   0.118647   0.107225   0.038447   0.091439   1.0
# 30097   0.042385   0.028186   0.016542   0.039146   0.056171   0.023695   1.0
# 30098   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000   0.0
# 30099   0.107440  -0.003688   0.055695   0.082974   0.095887   0.103184   1.0
#
# [30100 rows x 151 columns]

# %%
X = gp_table.drop(['type'], axis=1)
y = gp_table['type']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
clf = RandomForestClassifier(n_estimators=1000)
clf = clf.fit(X_train, y_train)
predictions = clf.predict(X_test)
print(accuracy_score(predictions, y_test))
# Out:
# 0.9957918050941307

# %%
#filename = 'dina_model_RFC(1000)_pulse_noise_95.sav'
#joblib.dump(clf, filename)
# Out:
# ['dina_model_RFC(1000)_pulse_noise_95.sav']
